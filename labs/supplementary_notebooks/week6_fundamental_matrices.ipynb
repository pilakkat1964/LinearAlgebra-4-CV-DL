# %% [markdown]
# # Fundamental Matrices (Week 6)
#
# ## Objective
# Explore the role of fundamental matrices in epipolar geometry for Computer Vision.

# %%
%%sage
# Example: Determinants and Eigenvalues
F = matrix(3, [0, -1, 0, 1, 0, -2, 0, 2, 1]) # Fundamental matrix
properties = F.determinant(), F.eigenvalues()
show(properties)

# %% [markdown]
# ## Summary/Exercises
# - Compute determinants and eigenvalues of other epipolar matrices.
# - Discuss relationships between these properties.
