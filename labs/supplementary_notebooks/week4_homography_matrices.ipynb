# %% [markdown]
# # Homography Matrices (Week 4)
#
# ## Objective
# Understand the structure and functions of homography matrices through Singular Value Decomposition (SVD).

# %%
%%sage
# Example: SVD of a Transformation Matrix
H = matrix(SR, [[1, 2], [3, 4]])
U, S, V = H.singular_value_decomposition()
show(S)

# %% [markdown]
# ## Summary/Exercises
# - Analyze the singular values and their impact on transformations.
